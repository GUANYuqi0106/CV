# %%
#install
# !pip install pytesseract opencv-python matplotlib
# Out:
# Requirement already satisfied: pytesseract in d:\anacondaishere\lib\site-packages (0.3.13)
# Requirement already satisfied: opencv-python in d:\anacondaishere\lib\site-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in d:\anacondaishere\lib\site-packages (3.8.4)
# Requirement already satisfied: packaging>=21.3 in d:\anacondaishere\lib\site-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in d:\anacondaishere\lib\site-packages (from pytesseract) (10.3.0)
# Requirement already satisfied: numpy>=1.21.2 in d:\anacondaishere\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anacondaishere\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anacondaishere\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anacondaishere\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anacondaishere\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anacondaishere\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anacondaishere\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\anacondaishere\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
#import libraries
import cv2  #designed for computer vision and image processing
import pytesseract  #used for extracting text from images
import matplotlib.pyplot as plt  #create plots and display images

# %%
#read the image
image_path = 'picture.jpg'  # relative path
image = cv2.imread(image_path)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
#image preprocessing
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  #convert the image to grayscale
image_rgb = cv2.cvtColor(gray_image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
#binarization
_, binary_image = cv2.threshold(gray_image, 150, 255, cv2.THRESH_BINARY)

# %%
#display
plt.imshow(binary_image, cmap='gray')
plt.axis('off')
plt.show()
#the picture I used is a screenshot when browsing youtube

# %%
import pytesseract
# 设置 Tesseract 的路径
pytesseract.pytesseract.tesseract_cmd = r'D:\tesseract\tesseract.exe' 
print(pytesseract.get_tesseract_version())
# Out:
# 5.4.0.20240606

# %%
#apply OCR to recognize text and output the results
recognized_text = pytesseract.image_to_string(binary_image)
print(recognized_text)
# Out:
# PERCEPTRON
#
# Our Al Profiling Technology
#
# A technology empowers informed
# decisions and targeted approaches,
# analysing customer segments and
# behaviour.
